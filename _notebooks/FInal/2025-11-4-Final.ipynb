# %% [markdown]
# ---
# layout: default
# title: Final
# description: Final Project
# categories: ['Final']
# permalink: /final
# toc: True
# comments: True
# breadcrumb: True
# ---

# %% [markdown]
# #  Compare yourself to the beginning of the year
# # Remember key things from 3 sprints Tools, Fundamentals of JavaScript/Python,  West Coast Travel or Digital Famine.
# # How N@tM went?  Did you get a comment or two you liked?
# # What do you want to do next on project, given time?
# # What do you want to learn next in CompSci?
# # Analytics review.
# # MCQ review, score, correction, and approach
# # Something cool you'd like to share.

# %% [markdown]
# # <span style="color: lightblue;">CSP 1 Final Review</span>
#
# ---
#
# ## <span style="color: lightblue;">How I Have Changed Throughout the Trimester</span>
#
# ### <span style="color: lightblue;">My Coding Journey</span>
#
# At the start of the year, I was completely lost when in this class. I knew nothing about it and honestly felt scared for my grade. I thought I would need private tutors or extra classes just to keep up, and I felt isolated in the class with no one to turn to for help.
#
# **What changed everything:**
# - After forming groups in CSP instead of looking at my classmates as just teamates, I look at them now as close friends
# - I began understanding fundamental concepts like loops and algorithms through collaboration and practice
# - Eventually, I reached a point where I could help my friend Shayan when he got stuck, which showed me how far I'd come
#
# **Key accomplishments this trimester:**
# - Created Submodule 1 for our West Coast Journey project
# - Learned to write algorithms and implement loops
# - Explained the Python lesson on iterations to other peers
# - Got a book on Python and JavaScript to deepen my understanding on coding
#
# ---
#
# ### <span style="color: lightblue;">Growth Beyond Coding</span>
#
# My presentation skills improved dramatically with help from our Scrum Master, Akhil. He identified specific areas where I needed work and helped me address them:
#
# - Making better eye contact with the audience
# - Speaking louder and more confidently
# - Understanding that mistakes are part of learning—nothing bad happens if I mess up
#
# ---
#
# ### <span style="color: lightblue;">Overall Transformation</span>
#
# I've gone from being scared of coding to genuinely enjoying it and looking forward to learning more. This trimester taught me about GitHub, repositories, and programming fundamentals. Most importantly, I'm now confident in my abilities and proud of how much I've grown as both a coder and a presenter.
#
# ---
#
# ### <span style="color: lightblue;">Night at the Museum</span>
#
# - Had an amazing experience showcasing our work
# - Impressed by the diversity of CSSE projects
# - Successfully presented my module to visiting adults
# - Particularly enjoyed the gambling game demonstration
# - Notable turnout and engagement from visitors
#
# ---
#
# ## <span style="color: lightblue;">Future Project Plans</span>
#
# - Enhance visual appeal through CSS improvements
# - Implement additional interactive features
# - Optimize content with focused examples
# - Streamline information presentation
#
# ---
#
# ## <span style="color: lightblue;">Next CompSci Class</span>
#
# - Dive deeper into algorithms and data structures
# - Explore network security and website protection
# - Learn database management and implementation
#
# ---
#
# ## <span style="color: lightblue;">Analytics</span>
#
# ---
#
# ## <span style="color: lightblue;">Something Cool to Share</span>
